# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelwoldegiorgis/DEVOPSFORCICD/blob/master/timeserieshandson_aisha_07_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #We have to forecast next 12 months passengers count based on the previous data

# %%
#Prerequisite:
# Time Series model work only with one column

# %%
#Dataset Link: https://drive.google.com/file/d/1Jgtb03hYqQdZfD0wShjfBgRz8UA1xGWM/view?usp=sharing

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/AirPassengers.csv')
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
#convert the month column into datetime format
df['Month']=pd.to_datetime(df['Month'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    datetime64[ns]
#  1   #Passengers  144 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.4 KB

# %%
df
# Out:
#          Month  #Passengers
# 0   1949-01-01          112
# 1   1949-02-01          118
# 2   1949-03-01          132
# 3   1949-04-01          129
# 4   1949-05-01          121
# ..         ...          ...
# 139 1960-08-01          606
# 140 1960-09-01          508
# 141 1960-10-01          461
# 142 1960-11-01          390
# 143 1960-12-01          432
#
# [144 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Month          0
# #Passengers    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.index=df['Month']

# %%
df
# Out:
#                 Month  #Passengers
# Month
# 1949-01-01 1949-01-01          112
# 1949-02-01 1949-02-01          118
# 1949-03-01 1949-03-01          132
# 1949-04-01 1949-04-01          129
# 1949-05-01 1949-05-01          121
# ...               ...          ...
# 1960-08-01 1960-08-01          606
# 1960-09-01 1960-09-01          508
# 1960-10-01 1960-10-01          461
# 1960-11-01 1960-11-01          390
# 1960-12-01 1960-12-01          432
#
# [144 rows x 2 columns]

# %%
del df['Month']

# %%
df
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121
# ...                 ...
# 1960-08-01          606
# 1960-09-01          508
# 1960-10-01          461
# 1960-11-01          390
# 1960-12-01          432
#
# [144 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 144 entries, 1949-01-01 to 1960-12-01
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #Passengers  144 non-null    int64
# dtypes: int64(1)
# memory usage: 2.2 KB

# %%
df.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
#STATIONARY data means data with constant mean and variance

# %%
#Adfuller: test to check whether the data is stationary or not
#null hypo: data is stationary
#alt hypo: data is not stationary

# %%
from statsmodels.tsa.stattools import adfuller

result=adfuller(df['#Passengers'])

p_val=result[1]
print(p_val)
# Out:
# 0.991880243437641

# %%
if p_val<0.05:
  print("We accept the null hypothesis - Data is stationary")
else:
  print("We reject the null hypothesis - Data is not stationary")
# Out:
# We reject the null hypothesis - Data is not stationary

# %%
#When data is not stationary, we can perform Detrend/Transformation

# %%
# window: taking last 12 months mean
rolling_mean=df.rolling(window=12).mean()

rolling_mean_detrend=df-rolling_mean
#subtract the rolling mean from actual passenger values : remove trend

# %%
rolling_mean_detrend.head(15)
# Out:
#             #Passengers
# Month
# 1949-01-01          NaN
# 1949-02-01          NaN
# 1949-03-01          NaN
# 1949-04-01          NaN
# 1949-05-01          NaN
# 1949-06-01          NaN
# 1949-07-01          NaN
# 1949-08-01          NaN
# 1949-09-01          NaN
# 1949-10-01          NaN
# 1949-11-01          NaN
# 1949-12-01    -8.666667
# 1950-01-01   -11.916667
# 1950-02-01    -1.583333
# 1950-03-01    12.666667

# %%
ax1=plt.subplot(1,2,2)
rolling_mean_detrend.plot(figsize=(12,4), color="tab:red", title='Differenced time series data', ax=ax1)
ax2=plt.subplot(1,2,1)
df.plot(figsize=(12,4),color='tab:red',title='original data', ax=ax2)
# Out:
# <Axes: title={'center': 'original data'}, xlabel='Month'>

# %%
detrend_data=rolling_mean_detrend.dropna() #smaller dataset

# %%
detrend_data
# Out:
#             #Passengers
# Month
# 1949-12-01    -8.666667
# 1950-01-01   -11.916667
# 1950-02-01    -1.583333
# 1950-03-01    12.666667
# 1950-04-01     6.166667
# ...                 ...
# 1960-08-01   142.666667
# 1960-09-01    40.916667
# 1960-10-01   -10.583333
# 1960-11-01   -83.916667
# 1960-12-01   -44.166667
#
# [133 rows x 1 columns]

# %%
result2=adfuller(detrend_data['#Passengers'])

p_val=result2[1]
print(p_val)
# Out:
# 0.022104139473878875

# %%
if p_val<0.05:
  print("We accept the null hypothesis - Data is stationary")
else:
  print("We reject the null hypothesis - Data is not stationary")
# Out:
# We accept the null hypothesis - Data is stationary

# %%
m=detrend_data.rolling(window=12).mean()
s=detrend_data.rolling(window=12).std()

# %%
plt.plot(detrend_data,color='blue',label='original')
plt.plot(m,color='red',label='rolling mean')
plt.plot(s,color='black',label='rolling std')
plt.legend(loc='best')
plt.title('Detrended Data with mean and std line')
# Out:
# Text(0.5, 1.0, 'Detrended Data with mean and std line')

# %%
# 133 rows -> 120 train, rest test

# %%
train=detrend_data[:120]['#Passengers']
test=detrend_data[120:]['#Passengers']

# %%
# p:How many past values we use to predict the next one.
# d:How many times we difference the data to make it stable (remove trend).
# q:How many past errors we use to correct predictions.

# %%
#AR: Autoregressive Model predicts your future values based on its own previous values
#MA: Moving Average forecasts future values by modelling the current value as a linear combination of past white noise error terms.

# %%
from statsmodels.tsa.arima.model import ARIMA

#order=>(p=AR,d=differencing,q=MA)
model=ARIMA(train, order=(1,0,2))

model_fit=model.fit()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
detrend_data['Predict']=model_fit.predict(start=len(train), end=len(train)+len(test)-1)
# Out:
# /tmp/ipykernel_6872/2793255442.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   detrend_data['Predict']=model_fit.predict(start=len(train), end=len(train)+len(test)-1)

# %%
detrend_data.tail(12)
# Out:
#             #Passengers    Predict
# Month
# 1960-01-01   -16.083333 -13.402469
# 1960-02-01   -46.166667   1.206088
# 1960-03-01   -19.250000   7.831010
# 1960-04-01    17.333333  10.835386
# 1960-05-01    24.000000  12.197859
# 1960-06-01    81.750000  12.815735
# 1960-07-01   162.583333  13.095940
# 1960-08-01   142.666667  13.223011
# 1960-09-01    40.916667  13.280638
# 1960-10-01   -10.583333  13.306771
# 1960-11-01   -83.916667  13.318622
# 1960-12-01   -44.166667  13.323997

# %%
detrend_data[['#Passengers','Predict']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
# print(np.__version__) #1st step

# %%
# !pip install numpy==1.26.4 pmdarima==2.0.4
#Step 2: run this command, restart session and then comment
#Step 3:import auto_arima

# %%
#AutoArima: finds the best model out of the time series model according to your dataset
from pmdarima import auto_arima

# %%
auto=auto_arima(detrend_data['#Passengers'])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ...

# %%
auto.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  133
# Model:               SARIMAX(3, 0, 2)   Log Likelihood                -612.905
# Date:                Sun, 07 Jun 2026   AIC                           1239.810
# Time:                        15:16:53   BIC                           1260.043
# Sample:                    12-01-1949   HQIC                          1248.032
#                          - 12-01-1960
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      6.8579      1.701      4.033      0.000       3.525      10.191
# ar.L1          0.8625      0.171      5.045      0.000       0.527       1.198
# ar.L2          0.2071      0.236      0.878      0.380      -0.255       0.670
# ...

# %%
#According to autoarima SARIMAX(3,0,2)is the best model for the given dataset

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
#order(3,0,2)(p,d,q)=> Non seasonal order
#seasonal order(3,0,2,12)(P,D,Q,S)=>
#P seasonal: Relationships with previous seasonal periods.
#D seasonal:  Seasonal differencing.
#Q seasonal: Errors from previous seasonal periods.
#Seasonality: Number of time steps per season (e.g., 12 for monthly data, 7 for weekly)

# %%
from statsmodels.tsa.statespace import sarimax

model=SARIMAX(train,order=(3,0,2),seasonal_order=(3,0,2,12)) #every 12 month pattern is repeating
model=model.fit()
# Out:
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.12/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...

# %%
detrend_data['Predict']=model.predict(start=len(train),end=len(train)+len(test)-1)
# Out:
# /tmp/ipykernel_6872/1712126754.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   detrend_data['Predict']=model.predict(start=len(train),end=len(train)+len(test)-1)

# %%
detrend_data[['#Passengers','Predict']].plot()
# Out:
# <Axes: xlabel='Month'>

# %%
forecast=model.forecast(steps=48) #48=len(len(x_test)+future) :len(x_test)=12 months(PRED) + 36 months(future)(FORECAST)

# %%
forecast
# Out:
# 1959-12-01    -42.011668
# 1960-01-01    -23.325939
# 1960-02-01    -47.993742
# 1960-03-01      9.597506
# 1960-04-01     -6.280826
# 1960-05-01     12.567501
# 1960-06-01     59.636339
# 1960-07-01    130.324231
# 1960-08-01    137.468830
# 1960-09-01     38.187274
# 1960-10-01    -19.496246
# 1960-11-01    -66.469315
# 1960-12-01    -47.684516
# 1961-01-01    -27.597221
# 1961-02-01    -51.303454
# 1961-03-01      6.511880
# 1961-04-01     -7.984401
# 1961-05-01     12.177870
# 1961-06-01     58.710495
# 1961-07-01    129.021629
# 1961-08-01    136.803383
# 1961-09-01     38.910197
# 1961-10-01    -17.130786
# 1961-11-01    -62.771490
# 1961-12-01    -45.221100
# 1962-01-01    -25.218837
# 1962-02-01    -49.297724
# 1962-03-01      7.200995
# 1962-04-01     -7.156562
# 1962-05-01     13.048937
# 1962-06-01     57.837146
# 1962-07-01    126.720926
# 1962-08-01    134.425864
# 1962-09-01     37.802229
# 1962-10-01    -16.793359
# 1962-11-01    -61.176757
# 1962-12-01    -44.944862
# ...

# %%
detrend_data.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
forecast.plot()
# Out:
# <Axes: >

# %%
#Prophet library
